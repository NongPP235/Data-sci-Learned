# %% [markdown]
# <a href="https://colab.research.google.com/github/NongPP235/Data-sci-Learned/blob/main/DS02_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
#
# จากข้อมูลที่กำหนดให้ จงเขียนโปรแกรมเพื่อหาคำตอบ พร้อมอธิบายผลลัพธ์ที่เกิดขึ้น
# 1. ลูกค้าคนที่ 5 "ยกเลิกใช้บริการ" หรือไม่
# 2. ลูกค้ารหัส "CUST008" มีการใช้งานครั้งสุดท้ายเมื่อไหร่ และความคิดเห็นต่อการใช้บริการเป็นอย่างไร
# 3. ลูกค้าที่ "ยังใช้บริการอยู่" เป็นผู้หญิงกี่คน ผู้ชายกี่คน
# 4. อายุเฉลี่ย ของลูกค้าที่เป็นผู้ชายที่ "ยังใช้บริการอยู่" คือเท่าไร
# 5. จงอธิบายลักษณะของลูกค้าที่ "ยกเลิกใช้บริการ" และ "ยังใช้บริการอยู่"

# %% [markdown]
# |index|customer\_id|age|gender|region|subscription\_type|monthly\_charges|data\_usage\_gb|contract\_type|customer\_service\_calls|churn\_status|last\_interaction\_date|feedback\_text|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |0|CUST001|35\.0|Male|North|Premium|75\.0|150\.0|Annual|2|No|2025-06-20|Great service, very reliable\.|
# |1|CUST002|28\.0|Female|South|Basic|30\.5|50\.0|Monthly|5|Yes|2025-06-15|Frequent outages, frustrated with support\.|
# |2|CUST003|42\.0|Male|East|Standard|50\.0|100\.0|Monthly|1|No|2025-06-22|No issues so far\.|
# |3|CUST004|55\.0|Female|West|Premium|80\.0|200\.0|Annual|0|No|2025-06-18|Happy with everything\.|
# |4|CUST005|NaN|Male|North|Basic|32\.0|60\.0|Monthly|3|Yes|2025-06-10|Slow internet, poor customer service\.|
# |5|CUST006|30\.0|Female|East|Standard|NaN|120\.0|Annual|1|No|2025-06-25|Good value for money\.|
# |6|CUST007|48\.0|Male|South|Premium|78\.0|180\.0|Annual|0|No|2025-06-21|Excellent speed\.|
# |7|CUST008|22\.0|Female|West|Basic|28\.0|40\.0|Monthly|4|Yes|2025-06-16|Always disconnecting\.|
# |8|CUST009|39\.0|Male|North|Standard|55\.0|110\.0|Annual|2|No|2025-06-19|Reliable, but a bit pricey\.|
# |9|CUST010|33\.0|Female|East|Premium|70\.0|NaN|Monthly|1|No|2025-06-23|Satisfied with the service\.|

# %%
import pandas as pd

# %%
fd = "/content/customer_data.csv"
ff = pd.read_csv(fd)

# %%
ff
# Out:
#   customer_id   age  gender region subscription_type  monthly_charges  \
# 0     CUST001  35.0    Male  North           Premium             75.0
# 1     CUST002  28.0  Female  South             Basic             30.5
# 2     CUST003  42.0    Male   East          Standard             50.0
# 3     CUST004  55.0  Female   West           Premium             80.0
# 4     CUST005   NaN    Male  North             Basic             32.0
# 5     CUST006  30.0  Female   East          Standard              NaN
# 6     CUST007  48.0    Male  South           Premium             78.0
# 7     CUST008  22.0  Female   West             Basic             28.0
# 8     CUST009  39.0    Male  North          Standard             55.0
# 9     CUST010  33.0  Female   East           Premium             70.0
#
#    data_usage_gb contract_type  customer_service_calls churn_status  \
# 0          150.0        Annual                       2           No
# ...

# %%
ff.describe()
# Out:
#              age  monthly_charges  data_usage_gb  customer_service_calls
# count   9.000000         9.000000       9.000000                10.00000
# mean   36.888889        55.388889     112.222222                 1.90000
# std    10.301025        21.391847      56.740148                 1.66333
# min    22.000000        28.000000      40.000000                 0.00000
# 25%    30.000000        32.000000      60.000000                 1.00000
# 50%    35.000000        55.000000     110.000000                 1.50000
# 75%    42.000000        75.000000     150.000000                 2.75000
# max    55.000000        80.000000     200.000000                 5.00000

# %%
#1
ff[ff['customer_id'] == 'CUST005']['churn_status']
# Out:
# 4    Yes
# Name: churn_status, dtype: object

# %%
#2
cus = (ff['customer_id'] == 'CUST008'	)
use = (ff['last_interaction_date'] == '2025-06-16')
col = ['customer_id','last_interaction_date','feedback_text']
cuse = cus & use

ff[cuse][col]
# Out:
#   customer_id last_interaction_date          feedback_text
# 7     CUST008            2025-06-16  Always disconnecting.

# %%
#3
# ch = (ff['churn_status'])
# col = ['gender','churn_status']

ff.loc[ff['churn_status'] == 'Yes',['gender','churn_status']].value_counts()
# Out:
# gender  churn_status
# Female  Yes             2
# Male    Yes             1
# Name: count, dtype: int64

# %%
#3
ff.loc[ff['churn_status'] == 'No',['gender','churn_status']].value_counts()
# Out:
# gender  churn_status
# Male    No              4
# Female  No              3
# Name: count, dtype: int64

# %%
#4
man = (ff['gender'] == 'Male')
ch = (ff['churn_status'] == 'No')
cols = ['customer_id','gender','age','churn_status']

md = man & ch
old = ff.loc[md, 'age'].mean()

print(old)
# Out:
# 41.0

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             10 non-null     object
#  1   age                     9 non-null      float64
#  2   gender                  10 non-null     object
#  3   region                  10 non-null     object
#  4   subscription_type       10 non-null     object
#  5   monthly_charges         9 non-null      float64
#  6   data_usage_gb           9 non-null      float64
#  7   contract_type           10 non-null     object
#  8   customer_service_calls  10 non-null     int64
#  9   churn_status            10 non-null     object
#  10  last_interaction_date   10 non-null     object
#  11  feedback_text           10 non-null     object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ KB

# %%
ff.head()
# Out:
#   customer_id   age  gender region subscription_type  monthly_charges  \
# 0     CUST001  35.0    Male  North           Premium             75.0
# 1     CUST002  28.0  Female  South             Basic             30.5
# 2     CUST003  42.0    Male   East          Standard             50.0
# 3     CUST004  55.0  Female   West           Premium             80.0
# 4     CUST005   NaN    Male  North             Basic             32.0
#
#    data_usage_gb contract_type  customer_service_calls churn_status  \
# 0          150.0        Annual                       2           No
# 1           50.0       Monthly                       5          Yes
# 2          100.0       Monthly                       1           No
# 3          200.0        Annual                       0           No
# 4           60.0       Monthly                       3          Yes
#
#   last_interaction_date                               feedback_text
# ...

# %%
ff.tail()
# Out:
#   customer_id   age  gender region subscription_type  monthly_charges  \
# 5     CUST006  30.0  Female   East          Standard              NaN
# 6     CUST007  48.0    Male  South           Premium             78.0
# 7     CUST008  22.0  Female   West             Basic             28.0
# 8     CUST009  39.0    Male  North          Standard             55.0
# 9     CUST010  33.0  Female   East           Premium             70.0
#
#    data_usage_gb contract_type  customer_service_calls churn_status  \
# 5          120.0        Annual                       1           No
# 6          180.0        Annual                       0           No
# 7           40.0       Monthly                       4          Yes
# 8          110.0        Annual                       2           No
# 9            NaN       Monthly                       1           No
#
#   last_interaction_date                feedback_text
# 5            2025-06-25        Good value for money.
# ...

# %%
ff.describe()
# Out:
#              age  monthly_charges  data_usage_gb  customer_service_calls
# count   9.000000         9.000000       9.000000                10.00000
# mean   36.888889        55.388889     112.222222                 1.90000
# std    10.301025        21.391847      56.740148                 1.66333
# min    22.000000        28.000000      40.000000                 0.00000
# 25%    30.000000        32.000000      60.000000                 1.00000
# 50%    35.000000        55.000000     110.000000                 1.50000
# 75%    42.000000        75.000000     150.000000                 2.75000
# max    55.000000        80.000000     200.000000                 5.00000
